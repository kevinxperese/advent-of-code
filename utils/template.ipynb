# %% [markdown]
# # {{DAY_LABEL}}
# {{URL}}

# %% [markdown]
# ## Parse the Input Data

# %%
def parse():
    """Parse puzzle input data."""
    with open(f'../inputs/day-{{DAY}}.txt') as f:
        foo = f.read()

# %% [markdown]
# ## Part 1
# ---

# %% [markdown]
# ### Run on Test Data

# %% [markdown]
# ### Run on Input Data

# %% [markdown]
# ## Part 2
# ---

# %% [markdown]
# ### Run on Test Data

# %% [markdown]
# ### Run on Input Data
