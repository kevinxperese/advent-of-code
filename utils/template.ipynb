# %% [markdown]
# # {{DAY_LABEL}}
# {{URL}}

# %% [markdown]
# ## Parse the Input Data

# %%
def parse(filename):
    """Parse puzzle input data."""
    with open(f'../inputs/{filename}.txt') as f:
        foo = f.read()

# %%
parse("day-{{DAY}}")

# %% [markdown]
# ## Part 1
# ---

# %%
def solve():
    pass

# %% [markdown]
# ### Run on Test Data

# %%
solve(parse("day-{{DAY}}_test")) == 0

# %% [markdown]
# ### Run on Input Data

# %%
solve(parse("day-{{DAY}}"))

# %% [markdown]
# ## Part 2
# ---

# %%
def solve2():
    pass

# %% [markdown]
# ### Run on Test Data

# %%
solve2(parse("day-{{DAY}}_test")) == 0

# %% [markdown]
# ### Run on Input Data

# %%
solve2(parse("day-{{DAY}}"))
